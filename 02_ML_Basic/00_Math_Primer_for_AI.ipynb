# %%
import numpy as np

# %% [markdown]
# #Matrix multiplication

# %%
a = np.array([[1, -3, 2], [4, 0, -5]])
print(a)
# Out:
# [[ 1 -3  2]
#  [ 4  0 -5]]

# %%
a.shape
# Out:
# (2, 3)

# %%
b = np.array([[3], [1], [2]])
print(b)
# Out:
# [[3]
#  [1]
#  [2]]

# %%
b.shape
# Out:
# (3, 1)

# %%
c = np.matmul(a, b) 
print(c)
# Out:
# [[4]
#  [2]]

# %%
d = np.dot(a, b)
print(d)
# Out:
# [[4]
#  [2]]

# %%
d.shape
# Out:
# (2, 1)
