# %%
def hello():
 print("Hello World")

# %%
hello()
# Out:
# Hello World

# %%
def hello(object):
 print("Hello " + object + "!")

# %%
hello("cat")
# Out:
# Hello cat!

# %%
def mySum(a, b):
    return a+b

# %%
c = mySum(2,3)
print(c)
# Out:
# 5

# %%
class Man:
  def __init__(self, name):
    self.name = name
    print("Initialized!")
  def hello(self):
    print("Hello " + self.name + " !")

  def goodbye(self):
    print("Good-bye " + self.name + " !")

# %%
m = Man("David")
# Out:
# Initialized!

# %%
m.hello()
# Out:
# Hello David !

# %%
m.goodbye()
# Out:
# Good-bye David !
